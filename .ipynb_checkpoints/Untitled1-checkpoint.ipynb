# %%
import ProduceMasks_wrapper as mask

# %%
mask.ProduceImageMasks('scene')
# Out:
# thresh.shape[0] 256
# thresh.shape[0] 256
# thresh.shape[0] 256
# thresh.shape[0] 256
# thresh.shape[0] 768
# thresh.shape[0] 1024
# thresh.shape[0] 1704
# thresh.shape[0] 2272
# thresh.shape[0] 2400
# thresh.shape[0] 1611
# thresh.shape[0] 2304
# thresh.shape[0] 3072
# thresh.shape[0] 1932
# thresh.shape[0] 2576
# thresh.shape[0] 768
# thresh.shape[0] 1024
# thresh.shape[0] 1623
# thresh.shape[0] 1260
# _atr file mislabeled for this object for cat and file:  road ../../adeContext-datasets/ADE20K/ADE20K_2016_07_26/images/training/s/shopfront/ADE_train_00000952
# not mask possible
# thresh.shape[0] 1920
# thresh.shape[0] 2560
# thresh.shape[0] 786
# thresh.shape[0] 1024
# thresh.shape[0] 361
# thresh.shape[0] 412
# thresh.shape[0] 1704
# thresh.shape[0] 2272
# thresh.shape[0] 768
# thresh.shape[0] 1024
# thresh.shape[0] 335
# thresh.shape[0] 502
# thresh.shape[0] 411
# thresh.shape[0] 640
# thresh.shape[0] 383
# thresh.shape[0] 510
# thresh.shape[0] 266
# thresh.shape[0] 400
# ...
